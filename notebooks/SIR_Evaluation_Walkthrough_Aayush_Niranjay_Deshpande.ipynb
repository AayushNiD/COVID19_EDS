# %%
# %load ../src/data/SIR_methods.py
import pandas as pd
import numpy as np

from datetime import datetime
import pandas as pd

from scipy import optimize
from scipy import integrate

N0 = 0
t = 0
SIR0 = 0


def SIR_modelling(y_data):
    global SIR0, t, N0

    ydata = np.array(y_data)
    t = np.arange(len(ydata))

    N0 = 100000000
    I0=ydata[0]
    S0=N0-I0
    R0=0
    SIR0 = (S0,I0,R0)


    popt = [0.2, 0.1]
    fit_odeint(t, *popt)

    popt, pcov = optimize.curve_fit(fit_odeint, t, ydata)
    perr = np.sqrt(np.diag(pcov))

    print('standard deviation errors : ',str(perr), ' start infect:',ydata[0])
    print("Optimal parameters: beta =", popt[0], " and gamma = ", popt[1])

    fitted=fit_odeint(t, *popt)

    return t, fitted

def SIR_model_t(SIR,t,beta,gamma):
    ''' Simple SIR model
        S: susceptible population
        t: time step, mandatory for integral.odeint
        I: infected people
        R: recovered people
        beta:

        overall condition is that the sum of changes (differnces) sum up to 0
        dS+dI+dR=0
        S+I+R= N (constant size of population)

    '''

    S,I,R=SIR
    dS_dt=-beta*S*I/N0
    dI_dt=beta*S*I/N0-gamma*I
    dR_dt=gamma*I
    return dS_dt,dI_dt,dR_dt

def fit_odeint(x, beta, gamma):
    return integrate.odeint(SIR_model_t, SIR0, t, args = (beta, gamma))[:,1]

# %%
# %load ../src/data/SIR_model.py
import pandas as pd
import numpy as np

import dash
dash.__version__
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output,State

import plotly.graph_objects as go
from scipy import optimize
from scipy import integrate

import os
print(os.getcwd())
df_analyse = pd.read_csv('../data/processed/COVID_final_set.csv', sep = ';')

fig = go.Figure()
app = dash.Dash()
app.layout = html.Div([

    dcc.Markdown('''

    # Implementation of SIR model for multiple countries

    '''),


    dcc.Dropdown(
        id = 'country_drop_down',
        options=[ {'label': each,'value':each} for each in df_analyse['country'].unique()],
        value= 'Germany', # which are pre-selected
        multi=False),

    dcc.Graph(figure = fig, id = 'SIR_graph')
    ])

def SIR(countries):

    SIR_modelling()


@app.callback(
    Output('SIR_graph', 'figure'),
    [Input('country_drop_down', 'value')])

def update_SIR_figure(country_drop_down):

    traces = []

    df_plot = df_analyse[df_analyse['country'] == country_drop_down]
    df_plot = df_plot[['state', 'country', 'confirmed', 'date']].groupby(['country', 'date']).agg(np.sum).reset_index()
    df_plot.sort_values('date', ascending = True).head()
    df_plot = df_plot.confirmed[35:]

    t, fitted = SIR_modelling(df_plot)

    traces.append(dict (x = t,
                        y = fitted,
                        mode = 'markers',
                        opacity = 0.9,
                        name = 'SIR-fit')
                  )

    traces.append(dict (x = t,
                        y = df_plot,
                        mode = 'lines',
                        opacity = 0.9,
                        name = 'Original Data')
                  )

    return {
            'data': traces,
            'layout': dict (
                width=1280,
                height=720,
                title = 'Model fitting for SIR',

                xaxis= {'title':'No. of Days',
                       'tickangle':-45,
                        'nticks':20,
                        'tickfont':dict(size=14,color="#7f7f7f"),
                      },

                yaxis={'title': "Population infected"}
        )
    }


if __name__ == '__main__':
    app.run_server(debug = True, use_reloader = False, port = 9000)
# Out:
# C:\Users\ADMIN\Covid-19_410622\notebooks
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
# Dash is running on http://127.0.0.1:9000/
#
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: on
# standard deviation errors :  [0.02337521 0.02333447]  start infect: 27.0
# Optimal parameters: beta = 0.8509912593070555  and gamma =  0.7863722101320004
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:57: RuntimeWarning:
#
# overflow encountered in double_scalars
#
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:58: RuntimeWarning:
#
# overflow encountered in double_scalars
#
# C:\Users\ADMIN\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: RuntimeWarning:
#
# overflow encountered in double_scalars
# standard deviation errors :  [0.03549562 0.03545905]  start infect: 2.0
# Optimal parameters: beta = 1.596779284567988  and gamma =  1.5231913104392754
# standard deviation errors :  [inf inf]  start infect: 0.0
# Optimal parameters: beta = 1.0  and gamma =  1.0
# standard deviation errors :  [0.01460813 0.01449798]  start infect: 453.0
# Optimal parameters: beta = 0.6481958281903908  and gamma =  0.5961536245106827
# standard deviation errors :  [inf inf]  start infect: 0.0
# Optimal parameters: beta = 1.0  and gamma =  1.0
# standard deviation errors :  [inf inf]  start infect: 0.0
# Optimal parameters: beta = 1.0  and gamma =  1.0
# standard deviation errors :  [0.00911881 0.00899775]  start infect: 139.0
# Optimal parameters: beta = 0.6103382857885115  and gamma =  0.5553863563787389
# standard deviation errors :  [0.06631672 0.06617241]  start infect: 22.0
# Optimal parameters: beta = 3.2441022760658123  and gamma =  3.194389452354369
# standard deviation errors :  [inf inf]  start infect: 0.0
# Optimal parameters: beta = 1.0  and gamma =  1.0
# standard deviation errors :  [0.01895705 0.01870012]  start infect: 13.0
# Optimal parameters: beta = 0.6593282623978307  and gamma =  0.5939403458531274
# standard deviation errors :  [0.07050536 0.07051549]  start infect: 1.0
# Optimal parameters: beta = 2.250903585810937  and gamma =  2.1793475197958703
# standard deviation errors :  [0.02337521 0.02333447]  start infect: 27.0
# Optimal parameters: beta = 0.8509912593070555  and gamma =  0.7863722101320004
# standard deviation errors :  [0.03938401 0.03935171]  start infect: 192.0
# Optimal parameters: beta = 0.9592433562911186  and gamma =  0.9228063638243722
# standard deviation errors :  [0.01124965 0.01130507]  start infect: 2.0
# Optimal parameters: beta = 0.5590765387500153  and gamma =  0.47348969617315667
# standard deviation errors :  [0.00444457 0.00444626]  start infect: 1.0
# Optimal parameters: beta = 0.32584144279741734  and gamma =  0.232135550277561
# standard deviation errors :  [0.03047081 0.03027369]  start infect: 15.0
# Optimal parameters: beta = 2.0971597699830595  and gamma =  2.048748022782948
# standard deviation errors :  [0.02337521 0.02333447]  start infect: 27.0
# Optimal parameters: beta = 0.8509912593070555  and gamma =  0.7863722101320004
# standard deviation errors :  [0.03047081 0.03027369]  start infect: 15.0
# Optimal parameters: beta = 2.0971597699830595  and gamma =  2.048748022782948
# standard deviation errors :  [0.02560618 0.02564693]  start infect: 1.0
# Optimal parameters: beta = 1.5557140652964723  and gamma =  1.4775527163453774
